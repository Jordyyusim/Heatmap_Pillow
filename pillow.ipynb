# %% [markdown]
# ### _PILLOW_
# ##### pip install pillow

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
#### .convert('L') = Black White
#### .convert('RGBA') = RGBA
#### .convert('CMYK') = CMYK

# %%
x = Image.open('panda.jpg').convert('L')
x
y = np.array(x)
y
y.shape
# Out:
# (338, 338)

# %%
plt.imshow(x)

# %%
pict = Image.fromarray(y, 'L')
pict.show()
# pict.save('namafile,jpg')

# %%
z = y.T
plt.imshow(z, cmap='gray')

# %%
### gambar udah ada warna ga bisa di heatmap

# %%
x = Image.open('mina.jpg').convert('L')
# x = np.array(x)
x
# x.shape
# Out:
# <PIL.Image.Image image mode=L size=700x450 at 0x1DE4438B6A0>

# %%
plt.figure('Mina', figsize=(20, 6))
plt.subplot(121)
plt.imshow(x, cmap = 'hot')
plt.subplot(122)
plt.imshow(x.T[::-1].T, cmap = 'gray')


plt.show()
